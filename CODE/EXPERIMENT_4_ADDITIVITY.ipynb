# %%
qc1 = QuantumCircuit(1)
qc1.rx(np.pi/4,0)
qc1.rx(np.pi/4,0)

qc2 = QuantumCircuit(1)
qc2.rx(np.pi/2,0)

sv1 = Statevector.from_instruction(qc1)
sv2 = Statevector.from_instruction(qc2)

print("Are states equal?",
      np.allclose(sv1.data, sv2.data))
